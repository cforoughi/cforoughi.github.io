# %% [markdown]
# # Acquisition Data

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('/Users/cforoughi/Dropbox/Medtech Digitization/1_Data/acq_python_2.csv')

# %%
data
# Out:
#              parent                                      child   dealdate
# 0        3D Systems                                       CRDM  20aug2013
# 1        3D Systems                           Medical Modeling  02apr2014
# 2        3D Systems                             Phenix Systems  15jul2013
# 3        3D Systems                                  Simbionix  28aug2014
# 4     3DISC Imaging                                   CoreWare  20dec2011
# 5                3M                Abzil Industria e Com̩rcio  02oct2007
# 6                3M                          Acolyte Biomedica  14feb2007
# 7                3M                         Aearo Technologies  01apr2008
# 8                3M                                    Arizant  13oct2010
# 9                3M                           Attenti Holdings  20oct2010
# 10               3M                                   Biotrace  28nov2006
# 11               3M                       Brontes Technologies  16oct2006
# ...

# %%
print len(data['child'].unique())
print len(data['parent'].unique())
print len(data['child'])
print len(data['parent'])
# Out:
# 4671
# 896
# 4671
# 4671

# %%
for index1, row1 in data.iterrows():
    for index2, row2 in data.iterrows():
         if row2['child']==row1['parent']:
            print row1['child']
            print index1
            print index2
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-105-9a8b36bad297> in <module>()
#       1 for index1, row1 in data.iterrows():
#       2     for index2, row2 in data.iterrows():
# ----> 3          if row2['child']==row1['parent']:
#       4             print row1['child']
#       5             print index1
#
# /Users/cforoughi/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     581         key = com._apply_if_callable(key, self)
#     582         try:
# --> 583             result = self.index.get_value(self, key)
#     584
#     585             if not lib.isscalar(result):
#
# /Users/cforoughi/anaconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_value(self, series, key)
#    1977         k = self._convert_scalar_indexer(k, kind='getitem')
#    1978         try:
# ...

# %%
for index1, row1 in data.iterrows():
    for index2, row2 in data.iterrows():
         if row1['child']==row2['parent']:
            data = data.append({'child':, 'parent':'black'}, ignore_index=True)

# %%
data_np = data.as_matrix()

# %%
print data_np
# Out:
# [['3D Systems' 'CRDM' '20aug2013']
#  ['3D Systems' 'Medical Modeling' '02apr2014']
#  ['3D Systems' 'Phenix Systems' '15jul2013']
#  ...,
#  ['\xc3\x83\xc2\x96ssur' 'Somas' '07feb2007']
#  ['\xc3\x83\xc2\x96ssur' 'TeamOlmed' '01oct2013']
#  ['\xc3\x83\xc2\x96ssur' 'Touch Bionics' '11apr2016']]

# %%
added = np.empty((0,3), int)
print added

for i in range(len(data_np)):
    for j in range(len(data_np)):
        #print data_np[i,0], data_np[j,1]
        if data_np[i,0]==data_np[j,1]:
            #print data_np[i,0], data_np[j,1]
            #print "YES"
            b = [[data_np[j,0], data_np[i,1], data_np[j,2]]]
            #print b
            added = np.append(added, b, axis=0)
            #print added
            print i
# Out:
# []
# 41
# 42
# 43
# 89
# 125
# 127
# 128
# 129
# 130
# 133
# 136
# 138
# 141
# 236
# 237
# 238
# 239
# 240
# 241
# 242
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 297
# 298
# 299
# 300
# 301
# 302
# 303
# 304
# 305
# 306
# 307
# 308
# 309
# 310
# 311
# 312
# 313
# 314
# 315
# 316
# 317
# 318
# 366
# 367
# 368
# 369
# 370
# 371
# 372
# 373
# 374
# 375
# 376
# 377
# 378
# 379
# 380
# 381
# 382
# 383
# 384
# 385
# 386
# 387
# 413
# 414
# 431
# 432
# 433
# 434
# 435
# 436
# 473
# 499
# 500
# 501
# 502
# 503
# 504
# 506
# 507
# 508
# 509
# 510
# 511
# 512
# 513
# 514
# 527
# 528
# 558
# 566
# 611
# 618
# 619
# 620
# 621
# 622
# 623
# 624
# 625
# 626
# 627
# 628
# 629
# 630
# 631
# 632
# 633
# 634
# 635
# 636
# ...

# %%
added
# Out:
# array([['Medtronic', '3F Therapeutics', '12aug2010'],
#        ['Medtronic', 'CryoCath Technologies', '12aug2010'],
#        ['Medtronic', 'EM Vascular', '12aug2010'],
#        ...,
#        ['Covidien', 'Micro Therapeutics', '12jul2010'],
#        ['Covidien', 'MicroVena', '12jul2010'],
#        ['Covidien', 'MitraLife', '12jul2010']],
#       dtype='|S58')

# %%
np.savetxt("../1_Data/acquisitions.csv", added, delimiter=",", fmt="%s")

# %%
print len(added)
# Out:
# 806
